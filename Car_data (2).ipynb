# %%
# Importing Libraries
import selenium
import pandas as pd
import time
from bs4 import BeautifulSoup

# Importing selenium webdriver 
from selenium import webdriver

# Importing required Exceptions which needs to handled
from selenium.common.exceptions import StaleElementReferenceException, NoSuchElementException

#Importing requests
import requests

# importing regex
import re

# %%
# Activating the chrome browser
driver=webdriver.Chrome("chromedriver.exe") 
time.sleep(2)

# opening cardekho.com
url = "https://www.cardekho.com/"
driver.get(url)
time.sleep(4)

driver.maximize_window()
time.sleep(2)

# %%
#Click on used car menu 
Used_car_click=driver.find_element_by_xpath('//span[@class="used-cars-india"]')
Used_car_click.click()
time.sleep(5)

# %%
#select the city 
city_click= driver.find_element_by_xpath('//a[@title="Used cars in  Ahmedabad"]')
city_click.click()
time.sleep(2)

# %%
   
for i in range(20):
    
    driver.execute_script("window.scrollTo(0, document.body.scrollHeight*0.92);")
    time.sleep(3)

    driver.execute_script("window.scrollTo(0, document.body.scrollHeight*0.97);")
    time.sleep(2)
   
    i=i+1

# %%
# scrape all Cars urls
Car_urls = []
url=driver.find_elements_by_xpath('//div[@class="gsc_col-xs-7  carsName"]/a')
for i in url:
        Car_urls.append(i.get_attribute("href"))

# %%
Links1=Car_urls
len(Car_urls)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-a7a12c4858aa> in <module>
# ----> 1 Links1=Car_urls
#       2 len(Car_urls)
#
# NameError: name 'Car_urls' is not defined

# %%
#Extracting for Banglore
#Click on used car menu 
Used_car_click=driver.find_element_by_xpath('//span[@class="used-cars-india"]')
Used_car_click.click()
time.sleep(5)

# %%
search= driver.find_element_by_xpath('//div[@class="inputfield"]')
search.click()

# %%
#select the city 
city_click= driver.find_element_by_xpath('//a[@title="Used cars in  Bangalore"]')
city_click.click()
time.sleep(2)

# %%
for i in range(150):
    
    driver.execute_script("window.scrollTo(0, document.body.scrollHeight*0.93);")
    time.sleep(2)

    driver.execute_script("window.scrollTo(0, document.body.scrollHeight*0.97);")
    time.sleep(3)
   
    i=i+1

# %%
# scrape all Cars urls for banglore
Car_urls1 = []
url1=driver.find_elements_by_xpath('//div[@class="gsc_col-xs-7  carsName"]/a')
for i in url1:
        Car_urls1.append(i.get_attribute("href"))

# %%
Links2=Car_urls1

# %%
len(Links2)
# Out:
# 1681

# %%
#Extracting for Delhi NCR
#Click on used car menu 
Used_car_click=driver.find_element_by_xpath('//span[@class="used-cars-india"]')
Used_car_click.click()
time.sleep(5)

# %%
search= driver.find_element_by_xpath('//div[@class="inputfield"]')
search.click()

# %%
#select the city 
city_click= driver.find_element_by_xpath('//a[@title="Used cars in  Delhi NCR"]')
city_click.click()
time.sleep(2)

# %%
for i in range(500):
    
    driver.execute_script("window.scrollTo(0, document.body.scrollHeight*0.97);")
    time.sleep(1)

    driver.execute_script("window.scrollTo(0, document.body.scrollHeight*0.98);")
    time.sleep(2)
    
    driver.execute_script("window.scrollTo(0, document.body.scrollHeight*0.90);")
    time.sleep(1)
   
    i=i+1

# %%
# scrape all Cars urls for Delhi NCR 
Car_urls2 = []
url2=driver.find_elements_by_xpath('//div[@class="gsc_col-xs-7  carsName"]/a')
for i in url2:
        Car_urls2.append(i.get_attribute("href"))

# %%
len(Car_urls2)
# Out:
# 3456

# %%
Links3= Car_urls2

# %%
#Extracting for Mumbi
#Click on used car menu 
Used_car_click=driver.find_element_by_xpath('//span[@class="used-cars-india"]')
Used_car_click.click()
time.sleep(5)

# %%
search= driver.find_element_by_xpath('//div[@class="inputfield"]')
search.click()

# %%
#select the city 
city_click= driver.find_element_by_xpath('//a[@title="Used cars in  Mumbai"]')
city_click.click()
time.sleep(2)

# %%
for i in range(500):
    
    driver.execute_script("window.scrollTo(0, document.body.scrollHeight*0.95);")
    time.sleep(1)

    driver.execute_script("window.scrollTo(0, document.body.scrollHeight*0.99);")
    time.sleep(1)
   
    i=i+1

# %%
# scrape all Cars urls for Mumbai
Car_urls3 = []
url3=driver.find_elements_by_xpath('//div[@class="gsc_col-xs-7  carsName"]/a')
for i in url3:
        Car_urls3.append(i.get_attribute("href"))

# %%
len(Car_urls3)
# Out:
# 2850

# %%
link4=Car_urls3

# %%
# Make Empty List of the required data
Brand= []
Model= []
Make_Year= []
Fuel=[]
KMs_Driven=[]
Engine_Displacement=[]
No_Of_Owner=[]
Transmission=[]
Mileage=[]
Max_Power=[]
Torque=[]

Seats=[]
Color=[]
Gear_Box=[]
Drive_Type=[]
Steering_Type=[]
Front_Brake_Type=[]
Rear_Brake_Type=[]

Acceleration=[]
Engine_Type=[] 
Price= []
Ahmedabad

# %%
for url in Car_urls:
    driver.get(url)
    time.sleep(2)
    
    
    
    # Extracting Price 
    try:
        price = driver.find_element_by_xpath('//div[@class="priceSection"]/span[2]')      
        Price.append(price.text)
    except:
        price1= driver.find_element_by_xpath("//span[@class='amount']")    
        Price.append(price1.text)

    time.sleep(1)
    
    # Extracting Brand from xpath
    try:
        brand = driver.find_element_by_xpath('//div[@class="gsc_col-xs-12"]/h1')      
        Brand.append(brand.text)
    except:
        brand1= driver.find_element_by_xpath("//div[@class='vdp-head']/h1[2]")    
        Brand.append(brand1.text)

    time.sleep(1)
    
    # Extracting make year
    try:
        year = driver.find_element_by_xpath('(//div[@class="iconDetail" or @class="fontweight500 value"])[1]')      
        Make_Year.append(year.text)
    except NoSuchElementException:
        Make_Year.append('-')

    time.sleep(1)
    
    
   # Extracting Fuel Type 
    try:
        fuel = driver.find_element_by_xpath('(//div[@class="fontweight500 value"])[3]')      
        Fuel.append(fuel.text)
    except:
        fuel1= driver.find_element_by_xpath('(//div[@class="iconDetail"])[5]')    
        Fuel.append(fuel1.text)

    time.sleep(1)
    
    # Extracting KM Driven  
    try:
        km_driven = driver.find_element_by_xpath('(//div[@class="fontweight500 value"])[4]')      
        KMs_Driven.append(km_driven.text)
    except:
        km_driven1= driver.find_element_by_xpath('(//div[@class="iconDetail"])[3]')    
        KMs_Driven.append(km_driven1.text)

    time.sleep(1)
    
    # Extracting Engine_Displacement  
    try:
        engine_displacement = driver.find_element_by_xpath('(//div[@class="fontweight500 value"])[5]')      
        Engine_Displacement.append(engine_displacement.text)
    except:
        engine_displacement1= driver.find_element_by_xpath('(//div[@class="largeSpec"])[2]')    
        Engine_Displacement.append(engine_displacement1.text)

    time.sleep(1)
    
    # Extracting No_Of_Owner
    try:
        no_Of_owner = driver.find_element_by_xpath('(//div[@class="fontweight500 value"])[6]')      
        No_Of_Owner.append(no_Of_owner.text)
    except:
        no_Of_owner1= driver.find_element_by_xpath('(//div[@class="iconDetail"])[4]')    
        No_Of_Owner.append(no_Of_owner1.text)

    time.sleep(1)
    
    # Extracting Transmission
    try:
        transmission = driver.find_element_by_xpath('(//div[@class="fontweight500 value"])[8]')      
        Transmission.append(transmission.text)
    except:
        transmission1= driver.find_element_by_xpath('(//div[@class="iconDetail"])[6]')    
        Transmission.append(transmission1.text)

    time.sleep(1)
    
    # Open full specification 
    try:
        driver.execute_script("window.scrollTo(0, document.body.scrollHeight*0.35);")
        time.sleep(1)
        Spec = driver.find_element_by_xpath("//div[text()='View All Specifications']")      
        Spec.click()
    except:
        full_spec=driver.find_element_by_xpath('(//div[@class="brdrBtm"]/a)[2]')
        full_spec.click()

    time.sleep(2)
    
        # Extracting Mileage
    try:
        mileage = driver.find_element_by_xpath('(//div[@class="fontweight500 value"])[10]')      
        Mileage.append(mileage.text)
    except:
        mileage1= driver.find_element_by_xpath('(//div[@class="largeSpec"])[1]')    
        Mileage.append(mileage1.text)

    time.sleep(1)
    
    # Extracting Max_Power
    try:
        max_power = driver.find_element_by_xpath('(//div[@class="fontweight500 value"])[12]')      
        Max_Power.append(max_power.text)
    except:
        max_power1= driver.find_element_by_xpath('(//div[@class="largeSpec"])[3]')    
        Max_Power.append(max_power1.text)

    time.sleep(1)
    
    # Extracting Torque
    try:
        torque = driver.find_element_by_xpath('(//div[@class="fontweight500 value"])[13]')      
        Torque.append(torque.text)
    except:
        torque1= driver.find_element_by_xpath('(//div[@class="largeSpec"])[4]')    
        Torque.append(torque1.text)

    time.sleep(1)
    
    # Extracting Seats
    try:
        seats = driver.find_element_by_xpath('//div[text()="Seats"]/following-sibling:: div')      
        Seats.append(seats.text)
    except NoSuchElementException:
        Seats.append('-')

    time.sleep(2)
    
    # Extracting Color
    try:
        color = driver.find_element_by_xpath('//div[text()="Color"]/following-sibling:: div')      
        Color.append(color.text)
    except NoSuchElementException:
        Color.append('-')

    time.sleep(2)
    
        # Extracting Gear_Box
    try:
        gear_Box = driver.find_element_by_xpath('//div[text()="Gear Box"]/following-sibling:: div')      
        Gear_Box.append(gear_Box.text)
    except NoSuchElementException:
        Color.append('-')

    time.sleep(2)
    
        
    # Extracting Drive_Type
    try:
        drive_Type = driver.find_element_by_xpath('//div[text( )="Drive Type"]/following-sibling:: div')      
        Drive_Type.append(drive_Type.text)
    except NoSuchElementException:
        Drive_Type.append('-')

    time.sleep(2)
    
        # Extracting Steering_Type
    try:
        steering_Type = driver.find_element_by_xpath('//div[text( )="Steering Type"]/following-sibling:: div ')      
        Steering_Type.append(steering_Type.text)
    except NoSuchElementException:
        Steering_Type.append('-')

    time.sleep(2)
    
        # Extracting Front_Brake_Type
    try:
        front_Brake_Type = driver.find_element_by_xpath('//div[text( )="Front Brake Type"]/following-sibling:: div')      
        Front_Brake_Type.append(front_Brake_Type.text)
    except NoSuchElementException:
        Front_Brake_Type.append('-')

    time.sleep(2)
    
    # Extracting Front_Brake_Type
    try:
        rear_Brake_Type = driver.find_element_by_xpath('//div[text( )="Rear Brake Type"]/following-sibling:: div ')      
        Rear_Brake_Type.append(rear_Brake_Type.text)
    except NoSuchElementException:
        Rear_Brake_Type.append('-')

    time.sleep(2)
    
        # Extracting Front_Brake_Type
    try:
        acceleration = driver.find_element_by_xpath('//div[text( )="Acceleration"]/following-sibling:: div ')      
        Acceleration.append(acceleration.text)
    except NoSuchElementException:
        Acceleration.append('-')

    time.sleep(2)
    
        # Extracting Front_Brake_Type
    try:
        engine_Type = driver.find_element_by_xpath('//div[text( )="Engine Type"]/following-sibling:: div ')      
        Engine_Type.append(engine_Type.text)
    except NoSuchElementException:
        Engine_Type.append('-')

    time.sleep(2)

# %%
# Making dataFrame for Ahmdabad cars
Ahmedabad=pd.DataFrame({})
Ahmedabad ['Brand']= Brand[:450]

Ahmedabad ['Make_Year']= Make_Year[:450]
Ahmedabad ['Fuel']=Fuel [:450]
Ahmedabad ['KMs_Driven']= KMs_Driven [:450]
Ahmedabad ['Engine_Displacement']= Engine_Displacement [:450]
Ahmedabad ['No_Of_Owner']= No_Of_Owner [:450]
Ahmedabad ['Transmission']= Transmission [:450]
Ahmedabad ['Mileage']= Mileage [:450]
Ahmedabad ['Max_Power']= Max_Power [:450]
Ahmedabad ['Torque']= Torque [:450]

Ahmedabad ['Seats']= Seats [:450]
Ahmedabad ['Color']= Color [:450]
Ahmedabad ['Gear_Box']= Gear_Box [:450]
Ahmedabad ['Drive_Type']= Drive_Type [:450]
Ahmedabad ['Steering_Type']= Steering_Type [:450]
Ahmedabad ['Front_Brake_Type']= Front_Brake_Type [:450]
Ahmedabad ['Rear_Brake_Type']= Rear_Brake_Type [:450]

Ahmedabad ['Acceleration']= Acceleration [:450]
Ahmedabad ['Engine_Type']= Engine_Type [:450]
Ahmedabad ['Price']= Price [:450]

# %%
data1= Ahmedabad.copy()

# %%
data1
# Out:
#                                 Brand Make_Year    Fuel  KMs_Driven  \
# 0             2020 Maruti Swift Dzire      2019  Petrol  11,935 Kms
# 1                 2016 Nissan Terrano      2016  Diesel  74,555 Kms
# 2             2020 Maruti Swift Dzire      2019  Petrol   9,379 Kms
# 3                   2018 Maruti Swift      2018  Diesel  31,824 Kms
# 4                  2017 Maruti Baleno      2017  Petrol  49,072 Kms
# ..                                ...       ...     ...         ...
# 445             Maruti Ciaz 1.3 Delta      2017  Diesel  87,000 kms
# 446     Hyundai Verna 1.6 SX CRDi (O)      2013  Diesel  83,000 kms
# 447      Hyundai Verna 1.6 CRDi AT SX      2015  Diesel  55,000 kms
# 448  Mahindra XUV500 2011-2015 W8 FWD      2012  Diesel  76,000 kms
# 449   Renault Duster 110PS Diesel RxZ      2013  Diesel  52,000 kms
#
#     Engine_Displacement   No_Of_Owner Transmission     Mileage   Max_Power  \
# 0               1197 cc     1st Owner       Manual  21.21 kmpl    81.80bhp
# 1               1461 cc     2nd Owner       Manual  20.45 kmpl     83.8bhp
# 2               1197 cc     1st Owner       Manual  21.21 kmpl    81.80bhp
# 3               1248 cc     1st Owner       Manual   28.4 kmpl       74bhp
# 4               1197 cc     1st Owner       Manual  21.01 kmpl    81.80bhp
# ..                  ...           ...          ...         ...         ...
# 445             1248 CC  Second Owner       Manual  28.09 kmpl    88.5 bhp
# 446             1582 CC   First Owner       Manual  22.32 kmpl  126.32 bhp
# 447             1582 CC   First Owner    Automatic  19.08 kmpl   126.2 bhp
# 448             2179 CC  Second Owner       Manual   15.1 kmpl     140 bhp
# 449             1461 CC   First Owner       Manual  19.01 kmpl  108.45 bhp
#
#                     Torque Seats  Color Gear_Box Drive_Type Steering_Type  \
# 0                    113Nm     5   Grey  5 Speed        FWD         Power
# 1                    200Nm     5  Black  5 Speed        FWD         Power
# 2                    113Nm     5  White  5 Speed        FWD         Power
# 3                    190Nm     5    Red        5        FWD         Power
# 4                    113Nm     5   Blue  5 Speed        FWD      Electric
# ..                     ...   ...    ...      ...        ...           ...
# 445         200Nm@ 1750rpm     5  White  6 Speed        FWD         Power
# 446  259.8Nm@ 1900-2750rpm     5  White  5 Speed        FWD         Power
# 447  259.9Nm@ 1900-2750rpm     5  White  5 Speed        FWD         Power
# 448    330Nm@ 1600-2800rpm     7   Grey  5 Speed        AWD         Power
# 449         248Nm@ 2250rpm     5  White  6 Speed        FWD         Power
#
#         Front_Brake_Type      Rear_Brake_Type   Acceleration  \
# 0                   Disc                 Drum   12.6 Seconds
# 1                   Disc                 Drum     14 Seconds
# 2                   Disc                 Drum   12.6 Seconds
# 3                   Disc                 Drum
# 4                   Disc                 Drum  12.36 seconds
# ..                   ...                  ...            ...
# 445      Ventilated Disc                 Drum     15 Seconds
# 446                 Disc                 Disc  10.62 Seconds
# 447                 Disc                 Drum  10.62 Seconds
# 448  Disc & Caliper Type  Disc & Caliper Type   12.5 Seconds
# 449      Ventilated Disc                 Drum              -
#
#               Engine_Type       Price
# 0     K Series VVT Engine    6,80,000
# 1       K9K Diesel Engine    4,70,500
# 2     K Series VVT Engine    6,75,000
# 3         DDiS 190 Engine    6,00,000
# 4         1.2L VVT Engine    6,10,000
# ..                    ...         ...
# 445       DDIS 200 Engine  5.75 Lakh*
# 446         Diesel Engine   5.4 Lakh*
# 447  U2 VGT Diesel Engine   6.9 Lakh*
# 448   mHawk Diesel Engine  5.25 Lakh*
# 449     dCi Diesel Engine   4.9 Lakh*
#
# [450 rows x 20 columns]

# %%
Ahmedabad.to_csv('Ahmedabad.csv')

# %%
# Make Empty List of the required data for Banglore
Brand1= []
Model1= []
Make_Year1= []
Fuel1=[]
KMs_Driven1=[]
Engine_Displacement1=[]
No_Of_Owner1=[]
Transmission1=[]
Mileage1=[]
Max_Power1=[]
Torque1=[]

Seats1=[]
Color1=[]
Gear_Box1=[]
Drive_Type1=[]
Steering_Type1=[]
Front_Brake_Type1=[]
Rear_Brake_Type1=[]

Acceleration1=[]
Engine_Type1=[] 
Price1= []

# %%
for url in Car_urls3:
    driver.get(url)
    time.sleep(2)
    print('Scraping URL',url )
    
    
        # Extracting Price 
    try:
        price = driver.find_element_by_xpath('//div[@class="priceSection"]/span[2]')      
        Price1.append(price.text)
    except:
        price1= driver.find_element_by_xpath("//span[@class='amount']")    
        Price1.append(price1.text)

    time.sleep(1)
    
    # Extracting Brand from xpath
    try:
        brand = driver.find_element_by_xpath('//div[@class="gsc_col-xs-12"]/h1')      
        Brand1.append(brand.text)
    except:
        brand1= driver.find_element_by_xpath("//div[@class='vdp-head']/h1[2]")    
        Brand1.append(brand1.text)

    time.sleep(1)
    
    # Extracting make year
    try:
        year = driver.find_element_by_xpath('(//div[@class="iconDetail" or @class="fontweight500 value"])[1]')      
        Make_Year1.append(year.text)
    except NoSuchElementException:
        Make_Year1.append('-')

    time.sleep(1)
    
    
   # Extracting Fuel Type 
    try:
        fuel = driver.find_element_by_xpath('(//div[@class="fontweight500 value"])[3]')      
        Fuel1.append(fuel.text)
    except:
        fuel1= driver.find_element_by_xpath('(//div[@class="iconDetail"])[5]')    
        Fuel1.append(fuel1.text)

    time.sleep(1)
    
    # Extracting KM Driven  
    try:
        km_driven = driver.find_element_by_xpath('(//div[@class="fontweight500 value"])[4]')      
        KMs_Driven1.append(km_driven.text)
    except:
        km_driven1= driver.find_element_by_xpath('(//div[@class="iconDetail"])[3]')    
        KMs_Driven1.append(km_driven1.text)

    time.sleep(1)
    
    # Extracting Engine_Displacement  
    try:
        engine_displacement = driver.find_element_by_xpath('(//div[@class="fontweight500 value"])[5]')      
        Engine_Displacement1.append(engine_displacement.text)
    except:
        engine_displacement1= driver.find_element_by_xpath('(//div[@class="largeSpec"])[2]')    
        Engine_Displacement1.append(engine_displacement1.text)

    time.sleep(1)
    
    # Extracting No_Of_Owner
    try:
        no_Of_owner = driver.find_element_by_xpath('(//div[@class="fontweight500 value"])[6]')      
        No_Of_Owner1.append(no_Of_owner.text)
    except:
        no_Of_owner1= driver.find_element_by_xpath('(//div[@class="iconDetail"])[4]')    
        No_Of_Owner1.append(no_Of_owner1.text)

    time.sleep(1)
    
    # Extracting Transmission
    try:
        transmission = driver.find_element_by_xpath('(//div[@class="fontweight500 value"])[8]')      
        Transmission1.append(transmission.text)
    except:
        transmission1= driver.find_element_by_xpath('(//div[@class="iconDetail"])[6]')    
        Transmission1.append(transmission1.text)

    time.sleep(1)
    
    # Open full specification 
    try:
        driver.execute_script("window.scrollTo(0, document.body.scrollHeight*0.35);")
        time.sleep(1)
        Spec = driver.find_element_by_xpath("//div[text()='View All Specifications']")      
        Spec.click()
    except NoSuchElementException:
        
        
    
    try:
        full_spec=driver.find_element_by_xpath('(//div[@class="brdrBtm"]/a)[2]')
        full_spec.click()
    except:
        full_spec=driver.find_element_by_xpath('(//div[@class="brdrBtm"]/a')
        full_spec.click()
        

    time.sleep(2)
    
        # Extracting Mileage
    try:
        mileage = driver.find_element_by_xpath('(//div[@class="fontweight500 value"])[10]')      
        Mileage1.append(mileage.text)
    except:
        mileage1= driver.find_element_by_xpath('(//div[@class="largeSpec"])[1]')    
        Mileage1.append(mileage1.text)

    time.sleep(1)
    
    # Extracting Max_Power
    try:
        max_power = driver.find_element_by_xpath('(//div[@class="fontweight500 value"])[12]')      
        Max_Power1.append(max_power.text)
    except:
        max_power1= driver.find_element_by_xpath('(//div[@class="largeSpec"])[3]')    
        Max_Power1.append(max_power1.text)

    time.sleep(1)
    
    # Extracting Torque
    try:
        torque = driver.find_element_by_xpath('(//div[@class="fontweight500 value"])[13]')      
        Torque1.append(torque.text)
    except:
        torque1= driver.find_element_by_xpath('(//div[@class="largeSpec"])[4]')    
        Torque1.append(torque1.text)

    time.sleep(1)
    
    # Extracting Seats
    try:
        seats = driver.find_element_by_xpath('//div[text()="Seats"]/following-sibling:: div')      
        Seats1.append(seats.text)
    except NoSuchElementException:
        Seats1.append('-')

    time.sleep(2)
    
    # Extracting Color
    try:
        color = driver.find_element_by_xpath('//div[text()="Color"]/following-sibling:: div')      
        Color1.append(color.text)
    except NoSuchElementException:
        Color1.append('-')

    time.sleep(1)
    
        # Extracting Gear_Box
    try:
        gear_Box = driver.find_element_by_xpath('//div[text()="Gear Box"]/following-sibling:: div')      
        Gear_Box1.append(gear_Box.text)
    except NoSuchElementException:
        Gear_Box1.append('-')

    time.sleep(1)
    
        
    # Extracting Drive_Type
    try:
        drive_Type = driver.find_element_by_xpath('//div[text( )="Drive Type"]/following-sibling:: div')      
        Drive_Type1.append(drive_Type.text)
    except NoSuchElementException:
        Drive_Type1.append('-')

    time.sleep(2)
    
        # Extracting Steering_Type
    try:
        steering_Type = driver.find_element_by_xpath('//div[text( )="Steering Type"]/following-sibling:: div ')      
        Steering_Type1.append(steering_Type.text)
    except NoSuchElementException:
        Steering_Type1.append('-')

    time.sleep(1)
    
        # Extracting Front_Brake_Type
    try:
        front_Brake_Type = driver.find_element_by_xpath('//div[text( )="Front Brake Type"]/following-sibling:: div')      
        Front_Brake_Type1.append(front_Brake_Type.text)
    except NoSuchElementException:
        Front_Brake_Type1.append('-')

    time.sleep(1)
    
    # Extracting Front_Brake_Type
    try:
        rear_Brake_Type = driver.find_element_by_xpath('//div[text( )="Rear Brake Type"]/following-sibling:: div ')      
        Rear_Brake_Type1.append(rear_Brake_Type.text)
    except NoSuchElementException:
        Rear_Brake_Type1.append('-')

    time.sleep(1)
    
        # Extracting Front_Brake_Type
    try:
        acceleration = driver.find_element_by_xpath('//div[text( )="Acceleration"]/following-sibling:: div ')      
        Acceleration1.append(acceleration.text)
    except NoSuchElementException:
        Acceleration1.append('-')

    time.sleep(1)
    
        # Extracting Front_Brake_Type
    try:
        engine_Type = driver.find_element_by_xpath('//div[text( )="Engine Type"]/following-sibling:: div ')      
        Engine_Type1.append(engine_Type.text)
    except NoSuchElementException:
        Engine_Type1.append('-')

    time.sleep(1)
# Out:
# Scraping URL https://www.cardekho.com/used-car-details/used-Mahindra-XUV500-2011-2015-W8-4WD-cars-Bangalore_8303E6E19D220BEE0ADC7C05CBD4A21D.htm
# ---------------------------------------------------------------------------
# NoSuchElementException                    Traceback (most recent call last)
# <ipython-input-68-325ad7cfd3b9> in <module>
#      90         time.sleep(1)
# ---> 91         Spec = driver.find_element_by_xpath("//div[text()='View All Specifications']")
#      92         Spec.click()
#
# ~\anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py in find_element_by_xpath(self, xpath)
#     393         """
# --> 394         return self.find_element(by=By.XPATH, value=xpath)
#     395
#
# ~\anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py in find_element(self, by, value)
#     975                 value = '[name="%s"]' % value
# --> 976         return self.execute(Command.FIND_ELEMENT, {
#     977             'using': by,
#
# ~\anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py in execute(self, driver_command, params)
#     320         if response:
# --> 321             self.error_handler.check_response(response)
#     322             response['value'] = self._unwrap_value(
#
# ~\anaconda3\lib\site-packages\selenium\webdriver\remote\errorhandler.py in check_response(self, response)
#     241             raise exception_class(message, screen, stacktrace, alert_text)
# --> 242         raise exception_class(message, screen, stacktrace)
#     243
#
# NoSuchElementException: Message: no such element: Unable to locate element: {"method":"xpath","selector":"//div[text()='View All Specifications']"}
#   (Session info: chrome=96.0.4664.45)
#
#
# During handling of the above exception, another exception occurred:
#
# StaleElementReferenceException            Traceback (most recent call last)
# <ipython-input-68-325ad7cfd3b9> in <module>
#      92         Spec.click()
#      93     except NoSuchElementException:
# ---> 94         Spec.click()
#      95
#      96
#
# ~\anaconda3\lib\site-packages\selenium\webdriver\remote\webelement.py in click(self)
#      78     def click(self):
#      79         """Clicks the element."""
# ---> 80         self._execute(Command.CLICK_ELEMENT)
#      81
#      82     def submit(self):
#
# ~\anaconda3\lib\site-packages\selenium\webdriver\remote\webelement.py in _execute(self, command, params)
#     631             params = {}
#     632         params['id'] = self._id
# --> 633         return self._parent.execute(command, params)
#     634
#     635     def find_element(self, by=By.ID, value=None):
#
# ~\anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py in execute(self, driver_command, params)
#     319         response = self.command_executor.execute(driver_command, params)
#     320         if response:
# --> 321             self.error_handler.check_response(response)
#     322             response['value'] = self._unwrap_value(
#     323                 response.get('value', None))
#
# ~\anaconda3\lib\site-packages\selenium\webdriver\remote\errorhandler.py in check_response(self, response)
#     240                 alert_text = value['alert'].get('text')
#     241             raise exception_class(message, screen, stacktrace, alert_text)
# --> 242         raise exception_class(message, screen, stacktrace)
#     243
#     244     def _value_or_default(self, obj, key, default):
#
# StaleElementReferenceException: Message: stale element reference: element is not attached to the page document
#   (Session info: chrome=96.0.4664.45)

# %%
# Making dataFrame for Banglore cars
Banglore=pd.DataFrame({})
Banglore ['Brand']= Brand1[:500]

Banglore ['Make_Year']= Make_Year1[:500]
Banglore ['Fuel']=Fuel1[:500]
Banglore ['KMs_Driven']= KMs_Driven1[:500]
Banglore ['Engine_Displacement']= Engine_Displacement1[:500]
Banglore ['No_Of_Owner']= No_Of_Owner1 [:500]
Banglore ['Transmission']= Transmission1[:500]
Banglore ['Mileage']= Mileage1 [:500]
Banglore ['Max_Power']= Max_Power1 [:500]
Banglore ['Torque']= Torque1 [:500]

Banglore ['Seats']= Seats1 [:500]
Banglore ['Color']= Color1[:500]
Banglore ['Gear_Box']= Gear_Box1 [:500]
Banglore ['Drive_Type']= Drive_Type1 [:500]
Banglore ['Steering_Type']= Steering_Type1 [:500]
Banglore ['Front_Brake_Type']= Front_Brake_Type1 [:500]
Banglore ['Rear_Brake_Type']= Rear_Brake_Type1 [:500]

Banglore ['Acceleration']= Acceleration1 [:500] 
Banglore ['Engine_Type']= Engine_Type1 [:500]
Banglore ['Price']= Price1 [:500]

# %%
Banglore.to_csv('Banglore.csv')

# %%
data2=Banglore.copy()

# %%
# Make Empty List of the required data for Banglore
Brand3= []
Model3= []
Make_Year3= []
Fuel3=[]
KMs_Driven3=[]
Engine_Displacement3=[]
No_Of_Owner3=[]
Transmission3=[]
Mileage3=[]
Max_Power3=[]
Torque3=[]

Seats3=[]
Color3=[]
Gear_Box3=[]
Drive_Type3=[]
Steering_Type3=[]
Front_Brake_Type3=[]
Rear_Brake_Type3=[]

Acceleration3=[]
Engine_Type3=[] 
Price3= []

# %%
#Mumbai
for url in Car_urls3[1050:]:
    driver.get(url)
    time.sleep(2)
    print('Scraping URL',url )
    
    
        # Extracting Price 
    try:
        price = driver.find_element_by_xpath('//div[@class="priceSection"]/span[2]')      
        Price3.append(price.text)
    except:
        price1= driver.find_element_by_xpath("//span[@class='amount']")    
        Price3.append(price1.text)

    time.sleep(1)
    
    # Extracting Brand from xpath
    try:
        brand = driver.find_element_by_xpath('//div[@class="gsc_col-xs-12"]/h1')      
        Brand3.append(brand.text)
    except:
        brand1= driver.find_element_by_xpath("//div[@class='vdp-head']/h1[2]")    
        Brand3.append(brand1.text)

    time.sleep(1)
    
    # Extracting make year
    try:
        year = driver.find_element_by_xpath('(//div[@class="iconDetail" or @class="fontweight500 value"])[1]')      
        Make_Year3.append(year.text)
    except NoSuchElementException:
        Make_Year3.append('-')

    time.sleep(1)
    
    
   # Extracting Fuel Type 
    try:
        fuel = driver.find_element_by_xpath('(//div[@class="fontweight500 value"])[3]')      
        Fuel3.append(fuel.text)
    except:
        fuel1= driver.find_element_by_xpath('(//div[@class="iconDetail"])[5]')    
        Fuel3.append(fuel1.text)

    time.sleep(1)
    
    # Extracting KM Driven  
    try:
        km_driven = driver.find_element_by_xpath('(//div[@class="fontweight500 value"])[4]')      
        KMs_Driven3.append(km_driven.text)
    except:
        km_driven1= driver.find_element_by_xpath('(//div[@class="iconDetail"])[3]')    
        KMs_Driven3.append(km_driven1.text)

    time.sleep(1)
    
    # Extracting Engine_Displacement  
    try:
        engine_displacement = driver.find_element_by_xpath('(//div[@class="fontweight500 value"])[5]')      
        Engine_Displacement3.append(engine_displacement.text)
    except:
        engine_displacement1= driver.find_element_by_xpath('(//div[@class="largeSpec"])[2]')    
        Engine_Displacement3.append(engine_displacement1.text)

    time.sleep(1)
    
    # Extracting No_Of_Owner
    try:
        no_Of_owner = driver.find_element_by_xpath('(//div[@class="fontweight500 value"])[6]')      
        No_Of_Owner3.append(no_Of_owner.text)
    except:
        no_Of_owner1= driver.find_element_by_xpath('(//div[@class="iconDetail"])[4]')    
        No_Of_Owner3.append(no_Of_owner1.text)

    time.sleep(1)
    
    # Extracting Transmission
    try:
        transmission = driver.find_element_by_xpath('(//div[@class="fontweight500 value"])[8]')      
        Transmission3.append(transmission.text)
    except:
        transmission1= driver.find_element_by_xpath('(//div[@class="iconDetail"])[6]')    
        Transmission3.append(transmission1.text)

    time.sleep(1)
    
    # Open full specification 
    try:
        driver.execute_script("window.scrollTo(0, document.body.scrollHeight*0.35);")
        time.sleep(1)
        Spec = driver.find_element_by_xpath("//div[text()='View All Specifications']")      
        Spec.click()
    except:
        full_spec=driver.find_element_by_xpath('(//div[@class="brdrBtm"]/a)[2]')
        full_spec.click()

    time.sleep(2)
    
        # Extracting Mileage
    try:
        mileage = driver.find_element_by_xpath('(//div[@class="fontweight500 value"])[10]')      
        Mileage3.append(mileage.text)
    except:
        mileage1= driver.find_element_by_xpath('(//div[@class="largeSpec"])[1]')    
        Mileage3.append(mileage1.text)

    time.sleep(1)
    
    # Extracting Max_Power
    try:
        max_power = driver.find_element_by_xpath('(//div[@class="fontweight500 value"])[12]')      
        Max_Power3.append(max_power.text)
    except:
        max_power1= driver.find_element_by_xpath('(//div[@class="largeSpec"])[3]')    
        Max_Power3.append(max_power1.text)

    time.sleep(1)
    
    # Extracting Torque
    try:
        torque = driver.find_element_by_xpath('(//div[@class="fontweight500 value"])[13]')      
        Torque3.append(torque.text)
    except:
        torque1= driver.find_element_by_xpath('(//div[@class="largeSpec"])[4]')    
        Torque3.append(torque1.text)

    time.sleep(1)
    
    # Extracting Seats
    try:
        seats = driver.find_element_by_xpath('//div[text()="Seats"]/following-sibling:: div')      
        Seats3.append(seats.text)
    except NoSuchElementException:
        Seats3.append('-')

    time.sleep(1)
    
    # Extracting Color
    try:
        color = driver.find_element_by_xpath('//div[text()="Color"]/following-sibling:: div')      
        Color3.append(color.text)
    except NoSuchElementException:
        Color3.append('-')

    time.sleep(1)
    
        # Extracting Gear_Box
    try:
        gear_Box = driver.find_element_by_xpath('//div[text()="Gear Box"]/following-sibling:: div')      
        Gear_Box3.append(gear_Box.text)
    except NoSuchElementException:
        Gear_Box3.append('-')

    time.sleep(1)
    
        
    # Extracting Drive_Type
    try:
        drive_Type = driver.find_element_by_xpath('//div[text( )="Drive Type"]/following-sibling:: div')      
        Drive_Type3.append(drive_Type.text)
    except NoSuchElementException:
        Drive_Type3.append('-')

    time.sleep(1)
    
        # Extracting Steering_Type
    try:
        steering_Type = driver.find_element_by_xpath('//div[text( )="Steering Type"]/following-sibling:: div ')      
        Steering_Type3.append(steering_Type.text)
    except NoSuchElementException:
        Steering_Type3.append('-')

    time.sleep(1)
    
        # Extracting Front_Brake_Type
    try:
        front_Brake_Type = driver.find_element_by_xpath('//div[text( )="Front Brake Type"]/following-sibling:: div')      
        Front_Brake_Type3.append(front_Brake_Type.text)
    except NoSuchElementException:
        Front_Brake_Type3.append('-')

    time.sleep(1)
    
    # Extracting Front_Brake_Type
    try:
        rear_Brake_Type = driver.find_element_by_xpath('//div[text( )="Rear Brake Type"]/following-sibling:: div ')      
        Rear_Brake_Type3.append(rear_Brake_Type.text)
    except NoSuchElementException:
        Rear_Brake_Type3.append('-')

    time.sleep(1)
    
        # Extracting Front_Brake_Type
    try:
        acceleration = driver.find_element_by_xpath('//div[text( )="Acceleration"]/following-sibling:: div ')      
        Acceleration3.append(acceleration.text)
    except NoSuchElementException:
        Acceleration3.append('-')

    time.sleep(1)
    
        # Extracting Front_Brake_Type
    try:
        engine_Type = driver.find_element_by_xpath('//div[text( )="Engine Type"]/following-sibling:: div ')      
        Engine_Type3.append(engine_Type.text)
    except NoSuchElementException:
        Engine_Type3.append('-')

    time.sleep(1)
# Out:
# Scraping URL https://www.cardekho.com/used-car-details/used-Maruti-Ciaz-1.3-Delta-cars-Thane_02090DF8A5B16F3B9E4F870A6CFC58CF.htm
# Scraping URL https://www.cardekho.com/used-car-details/used-Maserati-Levante-Diesel-BSIV-cars-Mumbai_72663DFB2704157C141B63F72E0948EA.htm
# Scraping URL https://www.cardekho.com/used-car-details/used-Jaguar-F-Pace-2016-2021-Prestige-2.0-AWD-cars-Mumbai_C4A84E35D707211374FCF54C73BD500F.htm
# Scraping URL https://www.cardekho.com/used-car-details/used-Maruti-S-Cross-2017-2020-Sigma-DDiS-200-SH-cars-Mumbai_76A9A1186E010BD4C835C5A19C78CD6D.htm
# Scraping URL https://www.cardekho.com/used-car-details/used-MG-Hector-2019-2021-Sharp-AT-BSIV-cars-Mumbai_6BA68101BC606EAD969F92919DD3048A.htm
# Scraping URL https://www.cardekho.com/used-car-details/used-Honda-City-2008-2011-1.5-S-MT-cars-Mumbai_1266D0AC49B2A316962CB159C4232B0B.htm
# Scraping URL https://www.cardekho.com/used-car-details/used-Maruti-Swift-Dzire-2014-2017-LXI-cars-Navi-Mumbai_AF383D7A9CE7AFEC1A1342E223047C76.htm
# Scraping URL https://www.cardekho.com/used-car-details/used-Maruti-Ignis-1.2-Zeta-BSIV-cars-Thane_32F8AD3075684E25A78BBE7962FD3E6C.htm
# Scraping URL https://www.cardekho.com/used-car-details/used-Honda-City-2008-2011-1.5-V-MT-cars-Mumbai_01E33BBF8758E4A9ED130359E88DA222.htm
# Scraping URL https://www.cardekho.com/used-car-details/used-Maruti-Ertiga-2012-2015-VDI-cars-Mumbai_6CFBBB59212AF0969E16C8CC3DAEAD8A.htm
# Scraping URL https://www.cardekho.com/used-car-details/used-Maruti-Ritz-VXi-(ABS)-BS-IV-cars-Thane_7C896104AA9C5A36527471F6347E4BBC.htm
# Scraping URL https://www.cardekho.com/used-car-details/used-Tata-Tigor-XZA-Plus-AMT-cars-Mumbai_50884EED7B4040887C73EE89532C4133.htm
# Scraping URL https://www.cardekho.com/used-car-details/used-Honda-CR-V-2.4L-4WD-AT-cars-Mumbai_8CCE75142BEEB3B4569E49FCD23CC861.htm
# Scraping URL https://www.cardekho.com/used-car-details/used-Honda-City-2008-2011-1.5-V-MT-cars-Mumbai_C0AB06EBEE0F5ADC27431CB5F1AFA6F8.htm
# Scraping URL https://www.cardekho.com/used-car-details/used-Honda-City-2008-2011-1.5-S-AT-cars-Mumbai_BBFB84EA946C2492625ACAE475F0E16D.htm
# Scraping URL https://www.cardekho.com/used-car-details/used-Hyundai-i10-2007-2010-Magna-AT-cars-Mumbai_CF061544877B130D738E856F9BB51471.htm
# Scraping URL https://www.cardekho.com/used-car-details/used-Renault-Lodgy-110PS-RxZ-7-Seater-cars-Mumbai_D383B23FB86F8B69E15D7FE5BC8CE567.htm
# Scraping URL https://www.cardekho.com/used-car-details/used-Mercedes-Benz-New-C-Class-C-220-CDI-Style-cars-Mumbai_1BD680CBF0B3F0EEBEACADC87661CC41.htm
# Scraping URL https://www.cardekho.com/used-car-details/used-Maruti-Ciaz-Sigma-Diesel-cars-Mumbai_227E69F5E6299BAFE5ABF3BDB44ED53F.htm
# Scraping URL https://www.cardekho.com/used-car-details/used-Hyundai-Verna-2015-2016-1.6-VTVT-AT-S-Option-cars-Thane_564D333F5E77CD7501679A8CB793CA8F.htm
# Scraping URL https://www.cardekho.com/used-car-details/used-Mahindra-XUV500-2011-2015-W8-AWD-cars-Mumbai_F70695E77C520F21834B46B756E0E4EA.htm
# Scraping URL https://www.cardekho.com/used-car-details/used-BMW-M-Series-X5-M-cars-Pune_359DC48B9EFAFC4890984819C37733C5.htm
# Scraping URL https://www.cardekho.com/used-car-details/used-Honda-Amaze-2013-2016-S-AT-i-Vtech-cars-Mumbai_FE0E05AF882CF806C723712E66ED6CA1.htm
# Scraping URL https://www.cardekho.com/used-car-details/used-Skoda-Octavia-2013-2021-1.8-TSI-AT-Style-cars-Mumbai_7B0A6376211A196FFBA66637E3695C7E.htm
# Scraping URL https://www.cardekho.com/used-car-details/used-Toyota-Innova-2009-2011-2.5-GX-8-STR-cars-Mumbai_53A556D822007062DB5DC433BEA3F038.htm
# Scraping URL https://www.cardekho.com/used-car-details/used-Mercedes-Benz-M-Class-ML-350-CDI-cars-Mumbai_40F6A7DD44BE2695981AC577FB19ED37.htm
# Scraping URL https://www.cardekho.com/used-car-details/used-Mahindra-XUV500-2011-2015-W8-FWD-cars-Mumbai_546E6C62490201D280C1ABD84E6BF038.htm
# Scraping URL https://www.cardekho.com/used-car-details/used-Hyundai-i20-2009-2011-Asta-(o)-cars-Mumbai_1C493E00E47E519F41FDAAB8A77C1F57.htm
# Scraping URL https://www.cardekho.com/used-car-details/used-Toyota-Innova-Crysta-2016-2020-2.4-VX-MT-BSIV-cars-Mumbai_0AC630C322B4BABADE234D686A4A3850.htm
# Scraping URL https://www.cardekho.com/used-car-details/used-Hyundai-Santro-GS-zipPlus-cars-Mumbai_E460BC62858F2C10B7FF3EB86F61FE57.htm
# ---------------------------------------------------------------------------
# NoSuchElementException                    Traceback (most recent call last)
# <ipython-input-110-f6ef540d9020> in <module>
#      91         time.sleep(1)
# ---> 92         Spec = driver.find_element_by_xpath("//div[text()='View All Specifications']")
#      93         Spec.click()
#
# ~\anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py in find_element_by_xpath(self, xpath)
#     393         """
# --> 394         return self.find_element(by=By.XPATH, value=xpath)
#     395
#
# ~\anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py in find_element(self, by, value)
#     975                 value = '[name="%s"]' % value
# --> 976         return self.execute(Command.FIND_ELEMENT, {
#     977             'using': by,
#
# ~\anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py in execute(self, driver_command, params)
#     320         if response:
# --> 321             self.error_handler.check_response(response)
#     322             response['value'] = self._unwrap_value(
#
# ~\anaconda3\lib\site-packages\selenium\webdriver\remote\errorhandler.py in check_response(self, response)
#     241             raise exception_class(message, screen, stacktrace, alert_text)
# --> 242         raise exception_class(message, screen, stacktrace)
#     243
#
# NoSuchElementException: Message: no such element: Unable to locate element: {"method":"xpath","selector":"//div[text()='View All Specifications']"}
#   (Session info: chrome=96.0.4664.45)
#
#
# During handling of the above exception, another exception occurred:
#
# NoSuchElementException                    Traceback (most recent call last)
# <ipython-input-110-f6ef540d9020> in <module>
#      93         Spec.click()
#      94     except:
# ---> 95         full_spec=driver.find_element_by_xpath('(//div[@class="brdrBtm"]/a)[2]')
#      96         full_spec.click()
#      97
#
# ~\anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py in find_element_by_xpath(self, xpath)
#     392             element = driver.find_element_by_xpath('//div/td[1]')
#     393         """
# --> 394         return self.find_element(by=By.XPATH, value=xpath)
#     395
#     396     def find_elements_by_xpath(self, xpath):
#
# ~\anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py in find_element(self, by, value)
#     974                 by = By.CSS_SELECTOR
#     975                 value = '[name="%s"]' % value
# --> 976         return self.execute(Command.FIND_ELEMENT, {
#     977             'using': by,
#     978             'value': value})['value']
#
# ~\anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py in execute(self, driver_command, params)
#     319         response = self.command_executor.execute(driver_command, params)
#     320         if response:
# --> 321             self.error_handler.check_response(response)
#     322             response['value'] = self._unwrap_value(
#     323                 response.get('value', None))
#
# ~\anaconda3\lib\site-packages\selenium\webdriver\remote\errorhandler.py in check_response(self, response)
#     240                 alert_text = value['alert'].get('text')
#     241             raise exception_class(message, screen, stacktrace, alert_text)
# --> 242         raise exception_class(message, screen, stacktrace)
#     243
#     244     def _value_or_default(self, obj, key, default):
#
# NoSuchElementException: Message: no such element: Unable to locate element: {"method":"xpath","selector":"(//div[@class="brdrBtm"]/a)[2]"}
#   (Session info: chrome=96.0.4664.45)

# %%
len(Engine_Type3)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-314ce9980d96> in <module>
# ----> 1 len(Engine_Type3)
#
# NameError: name 'Engine_Type3' is not defined

# %%
# Making dataFrame for Mumbai cars
Mumbai=pd.DataFrame({})
Mumbai ['Brand']= Brand1[:648]

Mumbai ['Make_Year']= Make_Year1[:648]
Mumbai ['Fuel']=Fuel1[:648]
Mumbai ['KMs_Driven']= KMs_Driven1[:648]
Mumbai ['Engine_Displacement']= Engine_Displacement1[:648]
Mumbai ['No_Of_Owner']= No_Of_Owner1[:648]
Mumbai ['Transmission']= Transmission1[:648]
Mumbai ['Mileage']= Mileage1 [:648]
Mumbai ['Max_Power']= Max_Power1 [:648]
Mumbai ['Torque']= Torque1 [:648]

Mumbai ['Seats']= Seats1 [:648]
Mumbai ['Color']= Color1 [:648]
Mumbai ['Gear_Box']= Gear_Box1 [:648]
Mumbai ['Drive_Type']= Drive_Type1 [:648]
Mumbai ['Steering_Type']= Steering_Type1 [:648]
Mumbai ['Front_Brake_Type']= Front_Brake_Type1 [:648]
Mumbai ['Rear_Brake_Type']= Rear_Brake_Type1 [:648]

Mumbai ['Acceleration']= Acceleration1 [:648]
Mumbai ['Engine_Type']= Engine_Type1 [:648]
Mumbai ['Price']= Price1 [:648]

# %%
data3=Mumbai.copy()

# %%
Mumbai.to_csv('Mumbai.csv')

# %%
len(Engine_Type3)
# Out:
# 66

# %%
# Out:
#                    Brand Make_Year    Fuel   KMs_Driven Engine_Displacement  \
# 0     2017 Hyundai Xcent      2017  Petrol   32,540 Kms             1197 cc
# 1       2016 Hyundai i20      2015  Petrol   41,061 Kms             1197 cc
# 2       2019 Honda Amaze      2018  Petrol   40,674 Kms             1198 cc
# 3      2011 Toyota Etios      2011  Petrol   67,142 Kms             1496 cc
# 4       2018 Hyundai i20      2018  Petrol   19,274 Kms             1197 cc
# ..                   ...       ...     ...          ...                 ...
# 643  2020 Maruti Celerio      2020  Petrol   22,966 Kms              998 cc
# 644  2014 Maruti Wagon R      2014  Petrol   90,326 Kms              998 cc
# 645    2012 Maruti Swift      2012  Diesel  132,163 Kms             1248 cc
# 646   2016 Maruti Baleno      2016  Petrol   44,890 Kms             1197 cc
# 647      2016 Honda Jazz      2015  Petrol   89,110 Kms             1199 cc
#
#     No_Of_Owner Transmission        Mileage Max_Power    Torque Seats   Color  \
# 0     1st Owner       Manual      19.1 kmpl     82bhp     114Nm     5   Other
# 1     1st Owner       Manual      18.6 kmpl  81.83bhp   114.7Nm     5     Red
# 2     1st Owner       Manual      17.8 kmpl   86.7bhp     109Nm     5   White
# 3     1st Owner       Manual      17.6 kmpl        15         5     5   Other
# 4     1st Owner       Manual        21 kmpl  81.86bhp  114.74nm     5   White
# ..          ...          ...            ...       ...       ...   ...     ...
# 643   1st Owner    Automatic      21.4 kmpl   83.1bhp     115Nm     5   Other
# 644   1st Owner       Manual      18.7 kmpl   88.7bhp     110Nm     5  Orange
# 645   1st Owner       Manual  Comprehensive   1248 CC     74bhp     5    Blue
# 646   2nd Owner       Manual      21.4 kmpl   83.1bhp     115Nm     5     Red
# 647   1st Owner       Manual     23.65 kmpl   88.5bhp     200Nm     5   Other
#
#     Gear_Box Drive_Type Steering_Type Front_Brake_Type Rear_Brake_Type  \
# 0    5 Speed        FWD         Power             Disc            Drum
# 1    5 Speed        FWD         Power             Disc            Drum
# 2    5 Speed        FWD         Power             Disc            Drum
# 3                               Power
# 4    5 Speed                 Electric             Disc            Drum
# ..       ...        ...           ...              ...             ...
# 643  5 Speed        FWD         Power             Disc            Drum
# 644  5 Speed        FWD         Power             Disc            Drum
# 645  5 Speed        FWD         Power  Ventilated Disc            Drum
# 646  5 Speed        FWD         Power             Disc            Drum
# 647  5 Speed        FWD         Power  Ventilated Disc      Solid Disc
#
#       Acceleration               Engine_Type     Price
# 0     14.2 Seconds  Kappa VTVT Petrol Engine  5,97,000
# 1     13.2 Seconds  Kappa VTVT Petrol Engine  5,70,000
# 2       15 Seconds      i-VTEC Petrol Engine  6,00,000
# 3                                          -  3,49,500
# 4                         1.2 l Kappa petrol  7,80,000
# ..             ...                       ...       ...
# 643  12.36 seconds         VVT Petrol Engine  5,02,000
# 644   13.7 Seconds      i-VTEC Petrol Engine  3,26,500
# 645  13.75 Seconds        DDiS Diesel Engine  3,60,000
# 646  12.36 seconds         VVT Petrol Engine  5,32,000
# 647   13.5 Seconds    DDiS 200 Diesel Engine  4,60,000
#
# [648 rows x 20 columns]

# %%
#Click on used car menu 
Used_car_click=driver.find_element_by_xpath('//span[@class="used-cars-india"]')
Used_car_click.click()
time.sleep(5)

# %%
#select the city 
city_click= driver.find_element_by_xpath('//a[@title="Used cars in  Gurgaon"]')
city_click.click()
time.sleep(2)

# %%
for i in range(50):
    
    driver.execute_script("window.scrollTo(0, document.body.scrollHeight*0.92);")
    time.sleep(3)

    driver.execute_script("window.scrollTo(0, document.body.scrollHeight*0.97);")
    time.sleep(2)
   
    i=i+1

# %%
# scrape all Cars urls
Car_urls = []
url=driver.find_elements_by_xpath('//div[@class="gsc_col-xs-7  carsName"]/a')
for i in url:
        Car_urls.append(i.get_attribute("href"))

# %%
# Make Empty List of the required data for Gurgaon
Brand= []

Make_Year= []
Fuel=[]
KMs_Driven=[]
Engine_Displacement=[]
No_Of_Owner=[]
Transmission=[]
Mileage=[]
Max_Power=[]
Torque=[]

Seats=[]
Color=[]
Gear_Box=[]
Drive_Type=[]
Steering_Type=[]
Front_Brake_Type=[]
Rear_Brake_Type=[]

Acceleration=[]
Engine_Type=[] 
Price= []

# %%
for url in Car_urls[1010:]:
    driver.get(url)
    time.sleep(2)
    
    
    
    # Extracting Price 
    try:
        price = driver.find_element_by_xpath('//div[@class="priceSection"]/span[2]')      
        Price.append(price.text)
    except:
        price1= driver.find_element_by_xpath("//span[@class='amount']")    
        Price.append(price1.text)

    time.sleep(1)
    
    # Extracting Brand from xpath
    try:
        brand = driver.find_element_by_xpath('//div[@class="gsc_col-xs-12"]/h1')      
        Brand.append(brand.text)
    except:
        brand1= driver.find_element_by_xpath("//div[@class='vdp-head']/h1[2]")    
        Brand.append(brand1.text)

    time.sleep(1)
    
    # Extracting make year
    try:
        year = driver.find_element_by_xpath('(//div[@class="iconDetail" or @class="fontweight500 value"])[1]')      
        Make_Year.append(year.text)
    except NoSuchElementException:
        Make_Year.append('-')

    time.sleep(1)
    
    
   # Extracting Fuel Type 
    try:
        fuel = driver.find_element_by_xpath('(//div[@class="fontweight500 value"])[3]')      
        Fuel.append(fuel.text)
    except:
        fuel1= driver.find_element_by_xpath('(//div[@class="iconDetail"])[5]')    
        Fuel.append(fuel1.text)

    time.sleep(1)
    
    # Extracting KM Driven  
    try:
        km_driven = driver.find_element_by_xpath('(//div[@class="fontweight500 value"])[4]')      
        KMs_Driven.append(km_driven.text)
    except:
        km_driven1= driver.find_element_by_xpath('(//div[@class="iconDetail"])[3]')    
        KMs_Driven.append(km_driven1.text)

    time.sleep(1)
    
    # Extracting Engine_Displacement  
    try:
        engine_displacement = driver.find_element_by_xpath('(//div[@class="fontweight500 value"])[5]')      
        Engine_Displacement.append(engine_displacement.text)
    except:
        engine_displacement1= driver.find_element_by_xpath('(//div[@class="largeSpec"])[2]')    
        Engine_Displacement.append(engine_displacement1.text)

    time.sleep(1)
    
    # Extracting No_Of_Owner
    try:
        no_Of_owner = driver.find_element_by_xpath('(//div[@class="fontweight500 value"])[6]')      
        No_Of_Owner.append(no_Of_owner.text)
    except:
        no_Of_owner1= driver.find_element_by_xpath('(//div[@class="iconDetail"])[4]')    
        No_Of_Owner.append(no_Of_owner1.text)

    time.sleep(1)
    
    # Extracting Transmission
    try:
        transmission = driver.find_element_by_xpath('(//div[@class="fontweight500 value"])[8]')      
        Transmission.append(transmission.text)
    except:
        transmission1= driver.find_element_by_xpath('(//div[@class="iconDetail"])[6]')    
        Transmission.append(transmission1.text)

    time.sleep(1)
    
    # Open full specification 
    try:
        driver.execute_script("window.scrollTo(0, document.body.scrollHeight*0.35);")
        time.sleep(1)
        Spec = driver.find_element_by_xpath("//div[text()='View All Specifications']")      
        Spec.click()
    except:
        full_spec=driver.find_element_by_xpath('(//div[@class="brdrBtm"]/a)[2]')
        full_spec.click()

    time.sleep(2)
    
        # Extracting Mileage
    try:
        mileage = driver.find_element_by_xpath('(//div[@class="fontweight500 value"])[10]')      
        Mileage.append(mileage.text)
    except:
        mileage1= driver.find_element_by_xpath('(//div[@class="largeSpec"])[1]')    
        Mileage.append(mileage1.text)

    time.sleep(1)
    
    # Extracting Max_Power
    try:
        max_power = driver.find_element_by_xpath('(//div[@class="fontweight500 value"])[12]')      
        Max_Power.append(max_power.text)
    except:
        max_power1= driver.find_element_by_xpath('(//div[@class="largeSpec"])[3]')    
        Max_Power.append(max_power1.text)

    time.sleep(1)
    
    # Extracting Torque
    try:
        torque = driver.find_element_by_xpath('(//div[@class="fontweight500 value"])[13]')      
        Torque.append(torque.text)
    except:
        torque1= driver.find_element_by_xpath('(//div[@class="largeSpec"])[4]')    
        Torque.append(torque1.text)

    time.sleep(1)
    
    # Extracting Seats
    try:
        seats = driver.find_element_by_xpath('//div[text()="Seats"]/following-sibling:: div')      
        Seats.append(seats.text)
    except NoSuchElementException:
        Seats.append('-')

    time.sleep(2)
    
    # Extracting Color
    try:
        color = driver.find_element_by_xpath('//div[text()="Color"]/following-sibling:: div')      
        Color.append(color.text)
    except NoSuchElementException:
        Color.append('-')

    time.sleep(2)
    
        # Extracting Gear_Box
    try:
        gear_Box = driver.find_element_by_xpath('//div[text()="Gear Box"]/following-sibling:: div')      
        Gear_Box.append(gear_Box.text)
    except NoSuchElementException:
        Gear_Box.append('-')

    time.sleep(2)
    
        
    # Extracting Drive_Type
    try:
        drive_Type = driver.find_element_by_xpath('//div[text( )="Drive Type"]/following-sibling:: div')      
        Drive_Type.append(drive_Type.text)
    except NoSuchElementException:
        Drive_Type.append('-')

    time.sleep(2)
    
        # Extracting Steering_Type
    try:
        steering_Type = driver.find_element_by_xpath('//div[text( )="Steering Type"]/following-sibling:: div ')      
        Steering_Type.append(steering_Type.text)
    except NoSuchElementException:
        Steering_Type.append('-')

    time.sleep(2)
    
        # Extracting Front_Brake_Type
    try:
        front_Brake_Type = driver.find_element_by_xpath('//div[text( )="Front Brake Type"]/following-sibling:: div')      
        Front_Brake_Type.append(front_Brake_Type.text)
    except NoSuchElementException:
        Front_Brake_Type.append('-')

    time.sleep(2)
    
    # Extracting Front_Brake_Type
    try:
        rear_Brake_Type = driver.find_element_by_xpath('//div[text( )="Rear Brake Type"]/following-sibling:: div ')      
        Rear_Brake_Type.append(rear_Brake_Type.text)
    except NoSuchElementException:
        Rear_Brake_Type.append('-')

    time.sleep(2)
    
        # Extracting Front_Brake_Type
    try:
        acceleration = driver.find_element_by_xpath('//div[text( )="Acceleration"]/following-sibling:: div ')      
        Acceleration.append(acceleration.text)
    except NoSuchElementException:
        Acceleration.append('-')

    time.sleep(2)
    
        # Extracting Front_Brake_Type
    try:
        engine_Type = driver.find_element_by_xpath('//div[text( )="Engine Type"]/following-sibling:: div ')      
        Engine_Type.append(engine_Type.text)
    except NoSuchElementException:
        Engine_Type.append('-')

    time.sleep(2)
